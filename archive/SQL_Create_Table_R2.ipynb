# %%
import psycopg2
from sqlalchemy import create_engine
import io
import pandas as pd

engine = create_engine(
    'postgresql+psycopg2://hz2816:8168@34.148.107.47/project1')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#wei's drive
# %cd /content/drive/MyDrive/Columbia University/Spring 2023/COMS 4111 DATABASES/Project/P2/Table
# Out:
# /content/drive/MyDrive/Columbia University/Spring 2023/COMS 4111 DATABASES/Project/P2/Table

# %%
#import dataframe to database
def df_to_sql(df,table_name): 
  # Drop old table and create new empty table
  df.head(0).to_sql(table_name, engine, if_exists='replace',index=False)

  conn = engine.raw_connection()
  cur = conn.cursor()
  output = io.StringIO()
  df.to_csv(output, sep='\t', header=False, index=False)
  output.seek(0)
  contents = output.getvalue()
  cur.copy_from(output, table_name, null="") # null values become ''
  conn.commit()
  cur.close()
  conn.close()

# %%
def lower_col(df):
  dictionary = {}
  for col in df.columns:
    col1=col.replace(" ","_")
    dictionary[col]=col1.lower()

  return df.rename(columns=dictionary)

# %%
import pandas as pd
#Open Data frame
#all_data_df = pd.read_csv("/content/drive/MyDrive/All data.csv")
#all_data_df = pd.read_csv("All data.csv")
vehicle_df = pd.read_csv("modified_vehicle.csv")
manufacturer_df = pd.read_csv("modified_manufacturer.csv")
dealership_df = pd.read_csv("modified_dealer.csv")
insurance_df = pd.read_csv("modified_insurance.csv")
customer_df = pd.read_csv("modified_customer.csv")
salesman_df = pd.read_csv("modified_salesman.csv")
car_sale_transaction_df = pd.read_csv("modified_car_sale_transaction.csv")


vehicle_df=lower_col(vehicle_df)
manufacturer_df=lower_col(manufacturer_df)
dealership_df=lower_col(dealership_df)
insurance_df=lower_col(insurance_df)
customer_df=lower_col(customer_df)
salesman_df=lower_col(salesman_df)
car_sale_transaction_df=lower_col(car_sale_transaction_df)

# %%
df_to_sql(vehicle_df,"vehicle")
df_to_sql(manufacturer_df,"manufacturer")
df_to_sql(dealership_df,"dealership")
df_to_sql(insurance_df,"insurance")
df_to_sql(customer_df,"customer")
df_to_sql(salesman_df,"salesman")
df_to_sql(car_sale_transaction_df,"car_sale_transaction")

# %%
df_to_sql(manufacturer_df,"manufacturer")

# %%
dealership_df=dealership_df.drop_duplicates(subset=['d_id'], keep='last')
df_to_sql(dealership_df,"dealership")

# %%
import psycopg2
  
conn = psycopg2.connect(database="project1",
                        user='hz2816', password='8168', 
                        host='34.148.107.47', port=None
)
  
conn.autocommit = True
cursor = conn.cursor()

table=["vehicle", "manufacturer", "dealership", "insurance", "customer", "salesman", "car_sale_transaction"]
for num,df in enumerate([vehicle_df,manufacturer_df,dealership_df,insurance_df,customer_df,salesman_df,car_sale_transaction_df]):
  for col in df.columns:
    t=table[num]
    id = col
    code=f"ALTER TABLE {t} ADD PRIMARY KEY ({id});"
    print(code)
    if df[col].dtypes == "object":
      l=df[col].str.len().max()+1
      code=f"ALTER TABLE {t} ALTER COLUMN {id} TYPE VARCHAR({int(l)});"
      #print(code)
      #cursor.execute(code)
# Out:
# ALTER TABLE vehicle ADD PRIMARY KEY (v_id);
# ALTER TABLE vehicle ADD PRIMARY KEY (manufacturer);
# ALTER TABLE vehicle ADD PRIMARY KEY (model);
# ALTER TABLE vehicle ADD PRIMARY KEY (price_in_thousands);
# ALTER TABLE vehicle ADD PRIMARY KEY (transmission);
# ALTER TABLE vehicle ADD PRIMARY KEY (engine);
# ALTER TABLE vehicle ADD PRIMARY KEY (body_style);
# ALTER TABLE vehicle ADD PRIMARY KEY (color);
# ALTER TABLE manufacturer ADD PRIMARY KEY (type);
# ALTER TABLE manufacturer ADD PRIMARY KEY (manufacturer_name);
# ALTER TABLE manufacturer ADD PRIMARY KEY (headquarter);
# ALTER TABLE manufacturer ADD PRIMARY KEY (estimated_annual_revenue);
# ALTER TABLE manufacturer ADD PRIMARY KEY (employees);
# ALTER TABLE manufacturer ADD PRIMARY KEY (number_of_models_in_us);
# ALTER TABLE dealership ADD PRIMARY KEY (d_id);
# ALTER TABLE dealership ADD PRIMARY KEY (dealer_name);
# ALTER TABLE dealership ADD PRIMARY KEY (dealer_add);
# ALTER TABLE dealership ADD PRIMARY KEY (d_sale);
# ...

# %%
import psycopg2
  
conn = psycopg2.connect(database="project1",
                        user='hz2816', password='8168', 
                        host='34.148.107.47', port=None
)
  
conn.autocommit = True
cursor = conn.cursor()

table=["vehicle", "manufacturer", "dealership", "insurance", "customer", "salesman", "car_sale_transaction"]
for num,df in enumerate([vehicle_df,manufacturer_df,dealership_df,insurance_df,customer_df,salesman_df,car_sale_transaction_df]):
    t=table[num]
    
    code=f"\d {t};"
    print(code)
    #cursor.execute(code)
# Out:
# \d vehicle;
# \d manufacturer;
# \d dealership;
# \d insurance;
# \d customer;
# \d salesman;
# \d car_sale_transaction;

# %%
table=["vehicle", "manufacturer", "dealership", "insurance", "customer", "salesman", "car_sale_transaction"]
for num,df in enumerate([vehicle_df,manufacturer_df,dealership_df,insurance_df,customer_df,salesman_df,car_sale_transaction_df]):
  for col in df.columns:
    t=table[num]
    id = col
    #code=f"ALTER TABLE {t} ADD PRIMARY KEY ({id});"
    if df[col].dtypes == "object":
      l=df[col].str.len().max()+1
      code=f"ALTER TABLE car_sale_transaction ADD FOREIGN KEY ({id}) REFERENCES {t}({id});"
      print(code)
      
      #cursor.execute(code)
# Out:
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (v_id) REFERENCES vehicle(v_id);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (manufacturer) REFERENCES vehicle(manufacturer);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (model) REFERENCES vehicle(model);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (transmission) REFERENCES vehicle(transmission);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (engine) REFERENCES vehicle(engine);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (body_style) REFERENCES vehicle(body_style);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (color) REFERENCES vehicle(color);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (type) REFERENCES manufacturer(type);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (manufacturer_name) REFERENCES manufacturer(manufacturer_name);
# ALTER TABLE car_sale_transaction ADD FOREIGN KEY (headquarter) REFERENCES manufacturer(headquarter);
# ...

# %%
ALTER TABLE Persons
ADD PRIMARY KEY (ID);

# %%
all_data_df["Customer_ID"]=customer_df["Customer_ID"]
all_data_df[["Date","Customer_ID"]]
all_data_df

# %%
all_data_df.columns
# Out:
# Index(['Date', 'Customer Name', 'Dealer_Name', 'Company', 'Model', 'Year',
#        'Body Style', 'Engine', 'Transmission', 'Color', 'Price in thousands',
#        'Dealer_Add', 'Customer Address', 'CouncilArea', 'Phone', 'Gender',
#        'Annual Income', 'Dealer_Location', 'Dealer_No ', 'Dealer_Region',
#        'Customer_ID'],
#       dtype='object')

# %%
#Dealer ID dictionary
D_id={}
i=1
df0=all_data_df[["Dealer_No ","Dealer_Name"]]
for value in df0["Dealer_No "].unique():
  D_id[value]={}
  j=1
  df1=df0[df0["Dealer_No "]==value]
  #print(df1)
  for value1 in df1["Dealer_Name"].unique():
    D_id[value][value1]={}
    #df2 = df1[df1["Dealer_Name"]== value1]
    #print(df2)
    D_id[value][value1]=f"D{i}_S{j}"

    j +=1

  i+=1

# %%
for i in range(len(all_data_df)):
  all_data_df.loc[i, ["Dealer_ID"]]= D_id[all_data_df.loc[i]["Dealer_No "]][all_data_df.loc[i]["Dealer_Name"]]
  print(f"{i}/37000")

# %%
#Customer ID dictionary
C_id={}
num = 1
df0=all_data_df[["Customer Name","Customer Address"]]
added_list=[]
for i in range(len(df0)):
  value = df0.loc[i, ["Customer Name"]].to_string()
  value1 = df0.loc[i, ["Customer Address"]].to_string()
  #print(value)
  vset = (value,value1)
  if vset not in added_list:
    added_list.append(vset)
    C_id[(value,value1)]=f"C_{num}"
    num +=1
    print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 29732
# 29733
# 29734
# 29735
# 29736
# 29737
# 29738
# 29739
# 29740
# 29741
# 29742
# 29743
# 29744
# 29745
# 29746
# 29747
# 29748
# 29749
# 29750
# 29751
# 29752
# 29753
# 29754
# 29755
# 29756
# 29757
# 29758
# 29759
# 29760
# 29761
# 29762
# 29763
# 29764
# 29765
# 29766
# 29767
# 29768
# 29769
# 29770
# 29771
# 29772
# 29773
# 29774
# 29775
# 29776
# 29777
# 29778
# 29779
# 29780
# 29781
# 29782
# 29783
# 29784
# 29785
# 29786
# 29787
# 29788
# 29789
# 29790
# 29791
# 29792
# 29793
# 29794
# 29795
# 29796
# 29797
# 29798
# 29799
# 29800
# 29801
# 29802
# 29803
# 29804
# 29805
# 29806
# 29807
# 29808
# 29809
# 29810
# 29811
# 29812
# 29813
# 29814
# 29815
# 29816
# 29817
# 29818
# 29819
# 29820
# 29821
# 29822
# 29823
# 29824
# 29825
# 29826
# 29827
# 29828
# 29829
# 29830
# 29831
# 29832
# 29833
# 29834
# 29835
# 29836
# 29837
# 29838
# 29839
# 29840
# 29841
# 29842
# 29843
# 29844
# 29845
# 29846
# 29847
# 29848
# 29849
# ...

# %%
for i in range(len(all_data_df)):
  value = all_data_df.loc[i, ["Customer Name"]].to_string()
  value1 = all_data_df.loc[i, ["Customer Address"]].to_string()
  #print(value)
  vset = (value,value1)
  all_data_df.loc[i, ["C_ID"]]= C_id[vset]
  print(f"{i}/37000")
# Out:
# Streaming output truncated to the last 5000 lines.
# 29732/37000
# 29733/37000
# 29734/37000
# 29735/37000
# 29736/37000
# 29737/37000
# 29738/37000
# 29739/37000
# 29740/37000
# 29741/37000
# 29742/37000
# 29743/37000
# 29744/37000
# 29745/37000
# 29746/37000
# 29747/37000
# 29748/37000
# 29749/37000
# 29750/37000
# 29751/37000
# 29752/37000
# 29753/37000
# 29754/37000
# 29755/37000
# 29756/37000
# 29757/37000
# 29758/37000
# 29759/37000
# 29760/37000
# 29761/37000
# 29762/37000
# 29763/37000
# 29764/37000
# 29765/37000
# 29766/37000
# 29767/37000
# 29768/37000
# 29769/37000
# 29770/37000
# 29771/37000
# 29772/37000
# 29773/37000
# 29774/37000
# 29775/37000
# 29776/37000
# 29777/37000
# 29778/37000
# 29779/37000
# 29780/37000
# 29781/37000
# 29782/37000
# 29783/37000
# 29784/37000
# 29785/37000
# 29786/37000
# 29787/37000
# 29788/37000
# 29789/37000
# 29790/37000
# 29791/37000
# 29792/37000
# 29793/37000
# 29794/37000
# 29795/37000
# 29796/37000
# 29797/37000
# 29798/37000
# ...

# %%
import random
for i in range(len(all_data_df)):
  all_data_df.loc[i, ["S_ID"]]= f"S_{str(random.randint(1,1000))}"
  all_data_df.loc[i, ["I_ID"]]= f"I_{str(random.randint(0,50))}"
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 29732
# 29733
# 29734
# 29735
# 29736
# 29737
# 29738
# 29739
# 29740
# 29741
# 29742
# 29743
# 29744
# 29745
# 29746
# 29747
# 29748
# 29749
# 29750
# 29751
# 29752
# 29753
# 29754
# 29755
# 29756
# 29757
# 29758
# 29759
# 29760
# 29761
# 29762
# 29763
# 29764
# 29765
# 29766
# 29767
# 29768
# 29769
# 29770
# 29771
# 29772
# 29773
# 29774
# 29775
# 29776
# 29777
# 29778
# 29779
# 29780
# 29781
# 29782
# 29783
# 29784
# 29785
# 29786
# 29787
# 29788
# 29789
# 29790
# 29791
# 29792
# 29793
# 29794
# 29795
# 29796
# 29797
# 29798
# 29799
# 29800
# 29801
# 29802
# 29803
# 29804
# 29805
# 29806
# 29807
# 29808
# 29809
# 29810
# 29811
# 29812
# 29813
# 29814
# 29815
# 29816
# 29817
# 29818
# 29819
# 29820
# 29821
# 29822
# 29823
# 29824
# 29825
# 29826
# 29827
# 29828
# 29829
# 29830
# 29831
# 29832
# 29833
# 29834
# 29835
# 29836
# 29837
# 29838
# 29839
# 29840
# 29841
# 29842
# 29843
# 29844
# 29845
# 29846
# 29847
# 29848
# 29849
# ...

# %%
all_data_df.to_csv("./modified_all_data.csv")

# %%
vehicle_df.to_csv("./modified_vehicle.csv")
manufacturer_df.to_csv("./modified_manufacturer.csv")
insurance_df.to_csv("./modified_insurance.csv")

# %%
all_data_df.rename(columns={"Date": "Transaction_date", "Dealer_ID": "D_ID","Company":"Manufacturer_name"},inplace=True)
car_sale_transaction_df=all_data_df[["Transaction_date","V_ID","C_ID","S_ID","D_ID","I_ID","Manufacturer_name"]]
car_sale_transaction_df.to_csv("./modified_car_sale_transaction.csv")

# %%
all_data_df.columns
# Out:
# Index(['Transaction_date', 'Customer Name', 'Dealer_Name', 'Manufacturer_name',
#        'Model', 'Year', 'Body Style', 'Engine', 'Transmission', 'Color',
#        'Price in thousands', 'Dealer_Add', 'Customer Address', 'CouncilArea',
#        'Phone', 'Gender', 'Annual Income', 'Dealer_Location', 'Dealer_No ',
#        'Dealer_Region', 'Customer_ID', 'D_ID', 'C_ID', 'S_ID', 'I_ID',
#        'Vehicle_ID', 'V_ID'],
#       dtype='object')

# %%
customer_df=all_data_df[['C_ID','Customer Name', 'Customer Address',
       'Phone', 'Gender', 'Annual Income']]
customer_df=customer_df.drop_duplicates(subset=['C_ID'], keep='last')

# %%
customer_df.to_csv("./modified_customer.csv")

# %%
university_df=pd.read_csv('university info.csv')

# %%
# Using list() Function
col_list =  list(university_df["university"])
print(col_list)
# Out:
# ['Baghdad College of Pharmacy', "Tokai Women's College", 'K.N.Toosi University of Technology', 'Ahmedabad University', 'Ural State Academy of Mining and Geology', 'University of Sheffield', 'Dominican College of San Rafael', 'Perm State University', 'High Point University', 'Rajarata University of Sri Lanka', 'Central European University', 'Narendra Deva University of Agriculture and Technology', 'University of Shkodra "Luigj Gurakuqi"', 'Izmir Economic University', 'Toyama Medical and Pharmaceutical University', "Northwest Polytechnical University Xi'an", 'Plekhanov Russian Academy of Economics', 'Uttar Pradesh Technical University', 'Nanyang Technological University', 'Universidad Nacional Experimental Politécnica "Antonio José de Sucre"', 'Bogor Agricultural University', 'Dalian University of Foreign Language', 'International Business School of Scandinavia', 'Université du Sud, Toulon et Var', 'Jewish University in Moscow', 'Tokyo Medical and Dental University', 'Information and C
# ...

# %%
col_list[0]
# Out:
# 'Baghdad College of Pharmacy'

# %%
def random_uni(col_list):
  num = random.randint(0,1000)
  return col_list[num] 


all_data_df["C_university"]= all_data_df.apply(lambda row: random_uni(col_list))

# %%
for i in range(len(all_data_df)):
  num = random.randint(0,999)

  all_data_df.loc[i, ["C_University"]]= col_list[num]
  all_data_df.loc[i, ["S_University"]]= col_list[num]
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 29732
# 29733
# 29734
# 29735
# 29736
# 29737
# 29738
# 29739
# 29740
# 29741
# 29742
# 29743
# 29744
# 29745
# 29746
# 29747
# 29748
# 29749
# 29750
# 29751
# 29752
# 29753
# 29754
# 29755
# 29756
# 29757
# 29758
# 29759
# 29760
# 29761
# 29762
# 29763
# 29764
# 29765
# 29766
# 29767
# 29768
# 29769
# 29770
# 29771
# 29772
# 29773
# 29774
# 29775
# 29776
# 29777
# 29778
# 29779
# 29780
# 29781
# 29782
# 29783
# 29784
# 29785
# 29786
# 29787
# 29788
# 29789
# 29790
# 29791
# 29792
# 29793
# 29794
# 29795
# 29796
# 29797
# 29798
# 29799
# 29800
# 29801
# 29802
# 29803
# 29804
# 29805
# 29806
# 29807
# 29808
# 29809
# 29810
# 29811
# 29812
# 29813
# 29814
# 29815
# 29816
# 29817
# 29818
# 29819
# 29820
# 29821
# 29822
# 29823
# 29824
# 29825
# 29826
# 29827
# 29828
# 29829
# 29830
# 29831
# 29832
# 29833
# 29834
# 29835
# 29836
# 29837
# 29838
# 29839
# 29840
# 29841
# 29842
# 29843
# 29844
# 29845
# 29846
# 29847
# 29848
# 29849
# ...

# %%
all_data_df.to_csv("./modified_all_data.csv")

# %%
all_data_df.columns
# Out:
# Index(['Transaction_date', 'Customer Name', 'Dealer_Name', 'Manufacturer_name',
#        'Model', 'Year', 'Body Style', 'Engine', 'Transmission', 'Color',
#        'Price in thousands', 'Dealer_Add', 'Customer Address', 'CouncilArea',
#        'Phone', 'Gender', 'Annual Income', 'Dealer_Location', 'Dealer_No ',
#        'Dealer_Region', 'Customer_ID', 'D_ID', 'C_ID', 'S_ID', 'I_ID',
#        'Vehicle_ID', 'V_ID', 'C_university', 'C_University', 'S_University'],
#       dtype='object')

# %%
d_sale["D5_S3"]
# Out:
# 1920

# %%
dealer_df = all_data_df[['D_ID', 'Dealer_Name','Dealer_Add']]
d_sale = all_data_df.value_counts("D_ID")
df=pd.DataFrame(d_sale)

dealer_df
sale=[]
for id in dealer_df["D_ID"]:
  sale.append(d_sale[id])
#s_sale = all_data_df.value_counts("S_ID")
dealer_df["D_sale"]=sale
dealer_df.to_csv("./modified_dealer.csv")
# Out:
# <ipython-input-153-8254ee38d535>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dealer_df["D_sale"]=sale

# %%
s_sale = all_data_df.value_counts("S_ID")


salesman_df=pd.read_csv('Salesmancsv.csv')
salesman_df
s_id = []
s_sales= []
for id in salesman_df["id"]:
  sid=f"S_{id}"
  s_id.append(sid)
  s_sales.append(s_sale[sid])

salesman_df["S_ID"]=s_id
salesman_df["S_sales"]=s_sales
salesman_df=salesman_df[["S_ID","Salesman_name","S_sales","University"]]
salesman_df.rename(columns={"University":"S_University"},inplace = True)
salesman_df
salesman_df.to_csv("./modified_salesman.csv")

# %%
salesman_df=pd.read_csv('Salesmancsv.csv')
#= all_data_df[['S_ID', 'Dealer_Name','Dealer_Add']]
d_sale = all_data_df.value_counts("D_ID")
df=pd.DataFrame(d_sale)

dealer_df
sale=[]
for id in dealer_df["D_ID"]:
  sale.append(d_sale[id])
#s_sale = all_data_df.value_counts("S_ID")
dealer_df["D_sale"]=sale
dealer_df.to_csv("./modified_dealer.csv")

# %%
saleman

# %%
# Out:
#         Dealer_ID                          Dealer_Name          Dealer_Add  \
# 0      06457-3834  Buddy Storbeck's Diesel Service Inc        44 Walnut St
# 1      60504-7114                     C & M Motors Inc      4333 Ogden Ave
# 2      38701-8047                          Capitol KIA    3 Green Tree Trl
# 3      99301-3882               Chrysler of Tri-Cities     3203 W Marie St
# 4      53546-9427                    Chrysler Plymouth        6137 S Us-51
# ...           ...                                  ...                 ...
# 34727  53546-9427                    Chrysler Plymouth  6942 E McDowell Rd
# 34728  38701-8047                          Capitol KIA  8803 Research Blvd
# 34729  99301-3882               Chrysler of Tri-Cities       347 Walnut St
# 34730  53546-9427                    Chrysler Plymouth      4636 Ogden Ave
# 34731  38701-8047                          Capitol KIA  306 Green Tree Trl
#
# ...

# %%
import pandas as pd
#Open Data frame
#all_data_df = pd.read_csv("/content/drive/MyDrive/All data.csv")
all_data_df = pd.read_csv("All data.csv")


#Adding V-ID and C-ID
all_data_df["Vehicle_ID"]= all_data_df.index
all_data_df['Vehicle_ID'] = 'V_' + all_data_df['Vehicle_ID'].astype(str)

all_data_df["Customer_ID"]= all_data_df.index
all_data_df['Customer_ID'] = 'C_' + all_data_df['Customer_ID'].astype(str)

#vehicle table rename
all_data_df.rename(columns={"Company": "Manufacturer"},inplace=True)

#Dealership table rename
all_data_df.rename(columns={"Dealer_No ": "Dealer_ID"},inplace=True)

#Dealership table rename
all_data_df.rename(columns={"Date": "Purchase_Date"},inplace=True)

# %%
all_data_df.columns
# Out:
# Index(['Purchase_Date', 'Customer Name', 'Dealer_Name', 'Manufacturer',
#        'Model', 'Year', 'Body Style', 'Engine', 'Transmission', 'Color',
#        'Price in thousands', 'Dealer_Add', 'Customer Address', 'CouncilArea',
#        'Phone', 'Gender', 'Annual Income', 'Dealer_Location', 'Dealer_ID',
#        'Dealer_Region', 'Vehicle_ID', 'Customer_ID'],
#       dtype='object')

# %%
vehicle_df = all_data_df[["Vehicle_ID",'Manufacturer', 'Model', 'Price in thousands','Transmission',
                          'Engine','Body Style', 'Color']]
vehicle_df_2 = vehicle_df.iloc[[78],]
for grp, index in vehicle_df.groupby(["Manufacturer","Model"]).groups.items():
  vehicle_df_2 = pd.concat([vehicle_df_2,vehicle_df.iloc[[index[0]],]], ignore_index = True)

# %%
vehicle_df_2 = vehicle_df_2.iloc[1:,]

# %%
vehicle_ID = []
for i in vehicle_df_2.index:
  vehicle_ID.append("V_"+str(i))
vehicle_df_2['Vehicle_ID'] = vehicle_ID

# %%
vehicle_df_2
# Out:
#     Vehicle_ID Manufacturer    Model  Price in thousands Transmission  \
# 1          V_1        Acura  Integra                  45         Auto
# 2          V_2        Acura       RL                  17       Manual
# 3          V_3        Acura       TL                  24         Auto
# 4          V_4         Audi       A4                  12       Manual
# 5          V_5         Audi       A6                  24       Manual
# ..         ...          ...      ...                 ...          ...
# 151      V_151        Volvo      S40                  42         Auto
# 152      V_152        Volvo      S70                  22       Manual
# 153      V_153        Volvo      S80                  21       Manual
# 154      V_154        Volvo      V40                  18         Auto
# 155      V_155        Volvo      V70                  39         Auto
#
#                         Engine Body Style       Color
# 1    DoubleÂ Overhead Camshaft  Passenger       Black
# ...

# %%
Dealership_df = all_data_df[["Dealer_ID",'Dealer_Name', 'Dealer_Add', 'Vehicle_ID','Transmission',
                          'Dealer_Region']]
Dealership_df["Dealer_Sales"]=None
Dealership_df["Maufacturer_ID "]=None
# Out:
# <ipython-input-18-d5e12b95f86d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dealership_df["Dealer_Sales"]=None
# <ipython-input-18-d5e12b95f86d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dealership_df["Maufacturer_ID "]=None

# %%
vehicle_ID_2 = []
for id in Dealership_df['Vehicle_ID']:
  cond = vehicle_df['Vehicle_ID']==id
  manu = vehicle_df.loc[cond,]['Manufacturer'].values[0]
  model = vehicle_df.loc[cond,]['Model'].values[0]
  cond2 = (vehicle_df_2['Manufacturer'] == manu) & (vehicle_df_2['Model'] == model)
  vehicle_ID_2.append(vehicle_df_2.loc[cond2,]['Vehicle_ID'].values[0])

# %%
Dealership_df['Vehicle_ID'] = vehicle_ID_2
# Out:
# <ipython-input-20-e9d22342d589>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dealership_df['Vehicle_ID'] = vehicle_ID_2

# %%
Dealership_df.drop(labels = ['vehicle_ID'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-59616a7739ae> in <module>
# ----> 1 Dealership_df.drop(labels = ['vehicle_ID'], axis = 1, inplace = True)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
manu_name = []
for id in Dealership_df['Vehicle_ID']:
  cond = vehicle_df_2['Vehicle_ID'] == id
  manu_name.append(vehicle_df_2.loc[cond,]['Manufacturer'].values[0])

# %%
Dealership_df['Manufacturer_name'] = manu_name
# Out:
# <ipython-input-23-0ecbe3e53994>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dealership_df['Manufacturer_name'] = manu_name

# %%
Dealership_df.drop(labels = ["Maufacturer_ID "], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Dealership_df
# Out:
#         Dealer_ID                          Dealer_Name          Dealer_Add  \
# 0      06457-3834  Buddy Storbeck's Diesel Service Inc        44 Walnut St
# 1      60504-7114                     C & M Motors Inc      4333 Ogden Ave
# 2      38701-8047                          Capitol KIA    3 Green Tree Trl
# 3      99301-3882               Chrysler of Tri-Cities     3203 W Marie St
# 4      53546-9427                    Chrysler Plymouth        6137 S Us-51
# ...           ...                                  ...                 ...
# 34727  53546-9427                    Chrysler Plymouth  6942 E McDowell Rd
# 34728  38701-8047                          Capitol KIA  8803 Research Blvd
# 34729  99301-3882               Chrysler of Tri-Cities       347 Walnut St
# 34730  53546-9427                    Chrysler Plymouth      4636 Ogden Ave
# 34731  38701-8047                          Capitol KIA  306 Green Tree Trl
#
# ...

# %%
insurance_df.to_csv("./modified_insurance.csv")

# %%
dealershi

# %%
Customer_df = all_data_df[["Customer_ID",'Customer Name', 'Annual Income', 'Customer Address','Gender',
                          'Vehicle_ID',"Dealer_ID","Purchase_Date"]]


Customer_df["Education"]=None
Customer_df["Salesman_ID "]=None

Customer_df
# Out:
# <ipython-input-26-3eb050060747>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_df["Education"]=None
# <ipython-input-26-3eb050060747>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_df["Salesman_ID "]=None
#       Customer_ID Customer Name  Annual Income    Customer Address  Gender  \
# 0             C_0     Geraldine          13500       68 Studley St    Male
# 1             C_1           Gia        1480000        85 Turner St    Male
# ...

# %%
Customer_df['Vehicle_ID'] = vehicle_ID_2
# Out:
# <ipython-input-88-9be86b2b8517>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_df['Vehicle_ID'] = vehicle_ID_2

# %%
Customer_df
# Out:
#       Customer_ID Customer Name  Annual Income    Customer Address  Gender  \
# 0             C_0     Geraldine          13500       68 Studley St    Male
# 1             C_1           Gia        1480000        85 Turner St    Male
# 2             C_2        Gianna        1035000     25 Bloomburg St    Male
# 3             C_3       Giselle          13500  18/659 Victoria St    Male
# 4             C_4         Grace        1465000        5 Charles St    Male
# ...           ...           ...            ...                 ...     ...
# 34727     C_34727        Thomas        1480000         13 Burns St    Male
# 34728     C_34728        Amelie         888000       29A Murray St    Male
# 34729     C_34729          Loan         705000      147A Severn St    Male
# 34730     C_34730        Romane        1140000    12/37 Stephen St  Female
# 34731     C_34731         Manon        1020000    3 Tarrengower St    Male
#
#       Vehicle_ID   Dealer_ID Purchase_Date Education Salesman_ID
# ...

# %%
Manufacturer_df = pd.read_csv('/content/drive/MyDrive/Manu.csv')
Manufacturer_df =  Manufacturer_df.rename(columns = {'Brand':'Manufacturer_name',
                  'Headquarters':'Headquarter',
                  'Approximate Number of Models offered in the U.S. Market':'Number_of_models_in_US' })

# %%
Manufacturer_df
# Out:
#                                          Type Manufacturer_name  \
# 0                    Legacy U.S. manufacturer         Chevrolet
# 1                    Legacy U.S. manufacturer          Cadillac
# 2                    Legacy U.S. manufacturer             Buick
# 3                    Legacy U.S. manufacturer               GMC
# 4                    Legacy U.S. manufacturer              Ford
# 5                    Legacy U.S. manufacturer           Lincoln
# 6   Foreign manufacturer with U.S. operations            Toyota
# 7   Foreign manufacturer with U.S. operations             Lexus
# 8   Foreign manufacturer with U.S. operations          Chrysler
# 9   Foreign manufacturer with U.S. operations             Dodge
# 10  Foreign manufacturer with U.S. operations               RAM
# 11  Foreign manufacturer with U.S. operations              Jeep
# 12  Foreign manufacturer with U.S. operations             Honda
# 13  Foreign manufacturer with U.S. operations             Acura
# ...

# %%
Insurance_df = pd.read_csv('/content/drive/MyDrive/insurance2.csv')
Insurance_df.rename(columns = {'state':'Insurance_state'})
# Out:
#    insurance_id  Insurance_state  full_coverage  minimum_coverage  difference
# 0           I_0         Michigan           8723              5282        3441
# 1           I_1     Rhode Island           3847              1589        2258
# 2           I_2        Louisiana           3525              1329        2196
# 3           I_3         Kentucky           3418              1338        2079
# 4           I_4          Florida           3370              2565         805
# 5           I_5           Nevada           3190              1295        1895
# 6           I_6         Colorado           3164              1075        2089
# 7           I_7       New Jersey           3013              1182        1831
# 8           I_8  Washington D.C.           2793              1260        1533
# 9           I_9         New York           2752              1323        1429
# 10         I_10          Arizona           2699               980        1719
# ...

# %%
df_to_sql(vehicle_df_2,"vehicle")
df_to_sql(Dealership_df,"dealership")
df_to_sql(Customer_df,"customer")
df_to_sql(Manufacturer_df,"manufacturer")
df_to_sql(Insurance_df,"insurance")

# %%
company=all_data_df[["Company"]]
company.value_counts().index
# Out:
# MultiIndex([( 'Chevrolet',),
#             (     'Dodge',),
#             (      'Ford',),
#             ('Volkswagen',),
#             ('Mitsubishi',),
#             ('Mercedes-B',),
#             (  'Chrysler',),
#             ('Oldsmobile',),
#             (    'Toyota',),
#             (    'Nissan',),
#             (   'Mercury',),
#             (     'Lexus',),
#             (     'Volvo',),
#             (       'BMW',),
#             (   'Pontiac',),
#             (     'Honda',),
#             (     'Acura',),
#             (  'Cadillac',),
#             (  'Plymouth',),
#             (    'Saturn',),
#             (   'Lincoln',),
#             (      'Audi',),
#             (     'Buick',),
#             (    'Subaru',),
#             (      'Jeep',),
#             (   'Porsche',),
#             (   'Hyundai',),
#             (      'Saab',),
#             (  'Infiniti',),
#             (    'Jaguar',)],
#            names=['Company'])

# %%
import pandas as pd
#Open Data frame
all_data_df = pd.read_csv("All data.csv")
vehicle_df = all_data_df[['Company', 'Model', 'Price in thousands','Transmission',
                          'Engine','Body Style', 'Color']]
vehicle_df
# Out:
#           Company       Model  Price in thousands Transmission  \
# 0            Ford  Expedition                  26         Auto
# 1           Dodge     Durango                  19         Auto
# 2        Cadillac    Eldorado                  31       Manual
# 3          Toyota      Celica                  14       Manual
# 4           Acura          TL                  24         Auto
# ...           ...         ...                 ...          ...
# 34727        Ford    Explorer                  18         Auto
# 34728      Nissan       Quest                  12       Manual
# 34729   Chevrolet    Corvette                  46         Auto
# 34730  Oldsmobile  Silhouette                  15       Manual
# 34731      Toyota      Celica                  14       Manual
#
#                           Engine Body Style       Color
# 0      DoubleÂ Overhead Camshaft        SUV       Black
# 1      DoubleÂ Overhead Camshaft        SUV       Black
# ...

# %%
#import dataframe to database
def df_to_sql(df,table_name): 
  # Drop old table and create new empty table
  vehicle_df.head(0).to_sql(table_name, engine, if_exists='replace',index=False)

  conn = engine.raw_connection()
  cur = conn.cursor()
  output = io.StringIO()
  vehicle_df.to_csv(output, sep='\t', header=False, index=False)
  output.seek(0)
  contents = output.getvalue()
  cur.copy_from(output, table_name, null="") # null values become ''
  conn.commit()
  cur.close()
  conn.close()

# %%
import psycopg2
  
conn = psycopg2.connect(database="project1",
                        user='hz2816', password='8168', 
                        host='34.148.107.47', port=None
)
  
conn.autocommit = True
cursor = conn.cursor()

# %%
#example
sql = '''CREATE TABLE Test(employee_id int NOT NULL,\
employee_name char(20),\
employee_email varchar(30), employee_salary float);'''
  
cursor.execute(sql)
  
sql2 = '''COPY Test(employee_id,employee_name,\
employee_email,employee_salary)
FROM '/private/tmp/details.csv'
DELIMITER ','
CSV HEADER;'''
  
cursor.execute(sql2)
  
sql3 = '''select * from Test;'''
cursor.execute(sql3)
for i in cursor.fetchall():
    print(i)
  
conn.commit()
conn.close()
